# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/daniel/Documents/gw-between-spheres

# %%
from src import benchmark_plotting
from pathlib import Path
import json

import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''

root_path = Path(".")
data_path = root_path / "data"
plot_path = root_path / "plots_same_axis"

# %%
n_trials = 20
m = 4
n = 1
ylim = (0.5, 0.56)
for subsample_strategy in ["voronoi", "random", "arrange"]:
    trial_path = (
        data_path
        / f"{subsample_strategy}_trials"
        / f"{subsample_strategy}_trials_n{n_trials}_d{m}_d{n}.json"
    )
    benchmark_plotting.plot_trial_outcomes(trial_path, plot_path=plot_path, ylim=ylim)

# %%
# json.load(open(, "r"))
n_trials = 20
m = 8
subsample_strategy = "voronoi"
for subsample_strategy in ["voronoi", "random", "arrange"]:
    for n in range(2, 8):
        # trial_path = data_path / "arrange_trials" / "arrange_trials_n10.json"
        trial_path = data_path / f"{subsample_strategy}_trials" / f"{subsample_strategy}_trials_n{n_trials}_d{m}_d{n}.json"
        benchmark_plotting.plot_trial_outcomes(trial_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       6 for n in range(2, 8):
#       7     # trial_path = data_path / "arrange_trials" / "arrange_trials_n10.json"
#       8     trial_path = data_path / f"{subsample_strategy}_trials" / f"{subsample_strategy}_trials_n{n_trials}_d{m}_d{n}.json"
# ----> 9     benchmark_plotting.plot_trial_outcomes(trial_path)
#
# TypeError: plot_trial_outcomes() missing 1 required positional argument: 'plot_path'
