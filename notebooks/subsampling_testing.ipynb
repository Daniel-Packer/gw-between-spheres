# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
# Out:
# /home/daniel/Documents/gw-between-spheres

# %%
from src import point_arrangement
import matplotlib.pyplot as plt
from jax import numpy as jnp

# %%
pts, wghts = point_arrangement.get_voronoi_sphere_pts(2, 101, n_larger=int(1e6))

# %%
fig, ax = plt.subplots()
ax.scatter(pts[:, 0], pts[:, 1], s=wghts * 1000)
ax.set(aspect="equal")
# Out:
# [None]
